# %%
from pathlib import Path
import sys

# Shared_Functions root directory
project_root = Path.cwd().parent

sys.path.insert(0, str(project_root))

# from occurrence.spatial_thin import spatial_thin
from sdm.random_forest_sdm import random_forest_sdm

# random_forest_sdm(
#     occurrence_csv="/run/media/vincent/Extreme Pro/MyBiodiversity/Biodiversity/Resubmit/Optimized/data/Kenya_total_presence_points.csv",
#     predictor_folder="/home/vincent/Development/geospatial-analysis/Biodiversity-Project/Shared_Functions/GeoMeadian/outputs/Kenya_raw_1km",
#     output_folder="/home/vincent/Development/geospatial-analysis/Biodiversity-Project/Shared_Functions/GeoMeadian/outputs",
#     longitude_col="longitude",
#     latitude_col="latitude",
#     n_background=400,
#     correlation_threshold=0.75,
#     tune_hyperparameters=True,
#     n_iter_search=100
# )

# %%
# ============================================================================
# EXAMPLE USAGE
# ============================================================================
from sdm.random_forest_sdm import random_forest_sdm
    
occurrence_file = "/run/media/vincent/Extreme Pro/MyBiodiversity/Biodiversity/Resubmit/Optimized/data/Kenya_total_presence_points.csv"
predictor_dir = "/home/vincent/Development/geospatial-analysis/Biodiversity-Project/Shared_Functions/GeoMeadian/outputs/Kenya_raw_1km"
output_dir = "/home/vincent/Development/geospatial-analysis/Biodiversity-Project/Shared_Functions/GeoMeadian/outputs"

# ========================================================================
# Example 1: Basic usage with defaults
# ========================================================================
print("=" * 70)
print("EXAMPLE 1: Basic usage with defaults")
print("=" * 70)
results = random_forest_sdm(
    occurrence_csv=occurrence_file,
    predictor_folder=predictor_dir,
    output_folder=output_dir,
    # verbose=1,
    n_background=500,
    # pseudoabsence_method='random',
    cv_folds=5,
    # n_estimators_range=(50, 500, 100),
    # max_depth_range=(5, 30, 5)
)

# ========================================================================
# Print results
# ========================================================================
print("\n" + "=" * 70)
print("RESULTS SUMMARY")
print("=" * 70)
print(f"✓ Suitability layer saved to: {results['output_raster']}")
print(f"✓ Presences used: {results['occurrence_count']}")
print(f"✓ Absences generated: {results['pseudoabsence_count']}")
if results['best_cv_score'] is not None:
    print(f"✓ Best CV Score: {results['best_cv_score']:.4f}")
    print(f"✓ Optimal parameters: {results['best_params']}")
print(f"\n✓ Feature Importance (Top 5):")
for i, (name, imp) in enumerate(list(results['feature_importance'].items())[:5], 1):
    print(f"  {i}. {name}: {imp:.4f}")
# Out:
# ...
# EXAMPLE 1: Basic usage with defaults
# ...
#
# Loading predictor rasters...
# Found 6 predictor rasters
# Checking raster alignment...
#
# Loading occurrence records...
# Occurrences: 623
# Extracting predictor values...
# Generating 500 pseudo-absence points...
#
# Checking predictor correlation...
# Removing 5 correlated predictors
# Final predictors: 1
#
# Running hyperparameter tuning...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.7s
# ...
